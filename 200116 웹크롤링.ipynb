# %% [markdown]
# # 깃허브

# %%
print(type(1))
print(type(1.0))
print(1+2)
print(2-1)
print(2*3)
print(5/2)
print(5//2)
print(5%2)
print(1+2*3)
print((1+2)*3)

# %%
print(type('abc'))
print('abc')
print('안녕하세요')
print("1970's")
print('abc\n123')
print(len('abc'))
print(len('안녕하세요'))
'abcdef'[0]
'abcdef\n123'
print('ABC가나다'.encode('utf-8'))
print(b'ABC\xea\xb0\x80\xeb\x82\x98\xeb\x8b\xa4'.decode('utf-8'))

# %%
d={'a':1,'b':2}
for key in d:
    value=d[key]
    print(key,value)
for key, value in d.items():
    print(key,value)
    
s=1
while s<1000:
    print(s)
    s=s*2

# %%
d={'a':1,'b':2}
try:
    print(d['x'])
except:
    print('x is not found')

# %%
prompt=('What is the airspped velocity of an unladen swallow?')
try:
    response=input(prompt)
except:
    response=''

# %%
try:
    number1,number2=eval(input('두 숫자를 컴마로 분리하여 입력하세요'))
    result=number1/number2
    print('결과는', result,'입니다.')
except ZeroDivisionError:
    print('0으로 나누기')
except SyntaxError:
    print('입력에 컴마가 빠졌습니다.')
except:
    print('입력에 문제가 있습니다.')
else:
    print('예외는 없습니다.')
finally:
    print('finally절이 실행되었습니다.')

# %%
class Rect:
    def __init__(self,width,height):
        self.width=width
        self.height=height
        
    def area(self):
        return self.width*self.height
r= Rect(100,20)
print(r.width,r.height,r.area())

class Square(Rect):
    def __init__(self,width):
        super().__init__(width,width)

# %%
product=['커피','우유','바나나','감귤','화장지','장갑','이불','베개','장난감','음료수','빵']
while True:
    select_menu=int(input('1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기  :  '))
    if select_menu==1:
        print('-'*20)
        p=input('삽입하고자 하는 상품을 입력하세요.')
        n=int(input('삽입하고자 하는 위치를 입력하세요.'))
        product.insert(n,p)
        print('-'*20)
    elif select_menu==2:
        print('-'*20)
        p=input('삭제하고자 하는 상품을 입력하세요.')
        product.remove(p)
        print('-'*20)
    elif select_menu==3:
        print('-'*20)
        p=input('추가하고자 하는 상품을 입력하세요.')
        product.append(p)
        print('-'*20)
    elif select_menu==4:
        print('-'*20)
        p=input('검색하고자 하는 상품을 입력하세요.')
        print('-'*20)
        if p in product:
            print('{}가 있습니다.'.format(p))
        else:
            print('{}가 없습니다.'.format(p))
        print('-'*20)
    elif select_menu==5:
        print(product)
        print('-'*20)
    elif select_menu==0:
        break
    else:
        continue
# Out:
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기1
# --------------------
# 삽입하고자 하는 상품을 입력하세요.사과
# 삽입하고자 하는 위치를 입력하세요.4
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기5
# ['커피', '우유', '바나나', '감귤', '사과', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기2
# --------------------
# 삭제하고자 하는 상품을 입력하세요.사과
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기5
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵']
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기3
# --------------------
# 추가하고자 하는 상품을 입력하세요.사과
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기5
# ['커피', '우유', '바나나', '감귤', '화장지', '장갑', '이불', '베개', '장난감', '음료수', '빵', '사과']
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기4
# --------------------
# 검색하고자 하는 상품을 입력하세요.사과
# --------------------
# 사과가 있습니다.
# --------------------
# 1.삽입 2.삭제 3.추가 4.검색 5.리스트 보기 0.나가기0

# %%
from urllib.request import urlopen

f=urlopen('http://hanbit.co.kr')
#urllib.request에 포함되어있는 urlopen()함수에url을 지정하면 웹페이지를 추출가능
#urlopen()함수는 HTTPResponse 자료형의 파일객체를 반환
print(f.read())
#b'<!DOCTYPE html>\r\n<html lang="ko">...
#read() 메서드로 HTTP 응답 본문(bytes 자료형)을 추출
#HTTP 연결은 자동으로 닫히므로 따로 close() 함수를 호출하지 않아도 됨
print(f.read().decode('utf-8'))
print(f.status) #상태코드를 추출

print(f.getheader('Content-Type')) # HTTP 헤더의 값을 추출 -> 인코딩 방식 추출
# Out:
# b'<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<!--[if lte IE 8]>\r\n<script>\r\n  location.replace(\'/support/explorer_upgrade.html\');\r\n</script>\r\n<![endif]-->\r\n<meta charset="utf-8"/>\r\n<title>\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac</title>\r\n<link rel="shortcut icon" href="http://www.hanbit.co.kr/images/common/hanbit.ico"> \r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta property="og:type" content="website"/>\r\n<meta property="og:title" content="\xed\x95\x9c\xeb\xb9\x9b\xec\xb6\x9c\xed\x8c\x90\xeb\x84\xa4\xed\x8a\xb8\xec\x9b\x8c\xed\x81\xac"/>\r\n<meta property="og:description" content="\xec\xb6\x9c\xed\x8c\x90\xec\x82\xac, IT\xec\xa0\x84\xeb\xac\xb8\xec\x84\x9c, \xeb\x8c\x80\xed\x95\x99\xea\xb5\x90\xec\x9e\xac, \xea\xb2\xbd\xec\xa0\x9c\xea\xb2\xbd\xec\x98\x81, \xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4/\xec\x9c\xa0\xec\x95\x84, MAKE, \xec\x8b\xa4\xec\x9a\xa9/\xec\x97\xac\xed\x96\x89, \xec\xa0\x84
# ...

# %%
import sys
from urllib.request import urlopen
f=urlopen('http://www.hanbit.co.kr/store/books/full_book_list.html')

encoding=f.info().get_content_charset(failobj='utf-8')
print(encoding)
text=f.read().decode(encoding)
print(text)
# Out:
# utf-8
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <meta charset="utf-8"/>
# <title>한빛출판네트워크</title>
# <link rel="shortcut icon" href="http://www.hanbit.co.kr/images/common/hanbit.ico">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="한빛출판네트워크"/>
# <meta property="og:description" content="출판사, IT전문서, 대학교재, 경제경영, 어린이/유아, MAKE, 실용/여행, 전자책, 인터넷 강의"/>
# <meta property="og:image" content="http://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />
# <meta property="og:url" content="http://www.hanbit.co.kr/store/books/full_book_list.html"/>
# <link rel="canonical" href="http://www.hanbit.co.kr/store/books/full_book_list.html" />
# <meta name="keywords" content="책,전자책,ebook,출판사,동영상,콘텐츠,강의,자격증,대학교재" />
# ...

# %%
import sys
from urllib.request import urlopen
url=input('URL 입력 : ')
f=urlopen(url)
encoding=f.info().get_content_charset(failobj='utf-8')
print(encoding)
text=f.read().decode(encoding)
print(text)

# %%
import re
import sys
from urllib.request import urlopen

f=urlopen('http://www.hanbit.co.kr/store/books/full_book_list.html')
bytes_content=f.read()
scanned_text=bytes_content[:1024].decode('ascii',errors='replace')
match=re.search(r'charset=["\']?([\w-]+)',scanned_text)
if match:
    encoding=match.group(1)
else:
    encoding='utf-8'
print('encoding:',encoding,file=sys.stderr)
text=bytes_content.decode(encoding)
print(text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <meta charset="utf-8"/>
# <title>한빛출판네트워크</title>
# <link rel="shortcut icon" href="http://www.hanbit.co.kr/images/common/hanbit.ico">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="한빛출판네트워크"/>
# <meta property="og:description" content="출판사, IT전문서, 대학교재, 경제경영, 어린이/유아, MAKE, 실용/여행, 전자책, 인터넷 강의"/>
# <meta property="og:image" content="http://www.hanbit.co.kr/images/hanbitpubnet_logo.jpg" />
# <meta property="og:url" content="http://www.hanbit.co.kr/store/books/full_book_list.html"/>
# <link rel="canonical" href="http://www.hanbit.co.kr/store/books/full_book_list.html" />
# <meta name="keywords" content="책,전자책,ebook,출판사,동영상,콘텐츠,강의,자격증,대학교재" />
# ...

# %%
print('\n is an escape code')
print(r'\n is an escape code') #r(raw)을 문자열 앞에 써주면 \n을 문자열로 취급한다.
# Out:
#  is an escape code
# \n is an escape code

# %%
import re
print(re.search(r"a.*c",'abc123DEF'))
#<re.Match object; span=(0,3),match='abc'>
print(re.search(r"a.*D",'abc123DEF'))
# Out:
# <re.Match object; span=(0, 3), match='abc'>
# <re.Match object; span=(0, 7), match='abc123D'>

# %%
import re
print(re.search(r"\d",'abc123DEF'))
print(re.search("[\d]",'abc123DEF'))
print(re.search("[0-9]",'abc123DEF'))
# Out:
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(3, 4), match='1'>
# <re.Match object; span=(3, 4), match='1'>

# %%
import re
print(re.search(r"\D",'abc123DEF'))
print(re.search("\D",'abc123DEF'))
print(re.search("[^0-9]",'abc123DEF'))
# Out:
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 1), match='a'>

# %%
import re
print(re.search(r"\s",'\tabc123DEF'))
print(re.search('[\s]','\tabc123DEF'))
print(re.search("\s",'\nabc123DEF'))
# Out:
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(0, 1), match='\n'>

# %%
import re
print(re.search(r"\S",'        abc123DEF'))
print(re.search('[\t]','\tabc123DEF'))
print(re.search("[^\n]",'\nabc123DEF'))
# Out:
# <re.Match object; span=(8, 9), match='a'>
# <re.Match object; span=(0, 1), match='\t'>
# <re.Match object; span=(1, 2), match='a'>

# %%
import re 
print(re.search(r"\w",'abc123DEF'))
print(re.search("[a-zA-Z0-9_]",'abc123DEF'))
print(re.search(r"\W",'abc123DEF'))
print(re.search("[^a-zA-Z0-9_]",'\tabc123DEF'))
# Out:
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 1), match='a'>
# None
# <re.Match object; span=(0, 1), match='\t'>

# %%
import re
print(re.search(r"a.c",'abc123DEF'))
print(re.search(r"a.c",'akc123DEF'))
print(re.search(r"a.D",'abcD123EF'))
print(re.search(r"a.c",'a\nc123DEF'))
print(re.search(r"a.c",'a\nc123DEF',re.DOTALL))
# Out:
# <re.Match object; span=(0, 3), match='abc'>
# <re.Match object; span=(0, 3), match='akc'>
# None
# None
# <re.Match object; span=(0, 3), match='a\nc'>

# %%
import re
print(re.search(r"a.*c",'abc123DEF'))
print(re.search(r"a*D",'abbbbcD123EF'))
print(re.search(r"a.*D",'abc123DEF'))
# Out:
# <re.Match object; span=(0, 3), match='abc'>
# <re.Match object; span=(6, 7), match='D'>
# <re.Match object; span=(0, 7), match='abc123D'>

# %%
import re
print(re.search(r"\d.*\d",'abc123DEF'))
print(re.search(r"\d*\d",'abbbbcD123EF'))
print(re.search(r"\d.*\d",'abc123DEF'))
# Out:
# <re.Match object; span=(3, 6), match='123'>
# <re.Match object; span=(7, 10), match='123'>
# <re.Match object; span=(3, 6), match='123'>

# %%
import re # ca+t 는 a가 1번이상 반복되어야함.
print(re.search(r"ca+t",'abct'))
print(re.search(r"ca+t",'abcat'))
print(re.search(r"ca+t",'abcaaaaaaat'))
# Out:
# None
# <re.Match object; span=(2, 5), match='cat'>
# <re.Match object; span=(2, 11), match='caaaaaaat'>

# %%
import re
print(re.search(r"ca{2,5}t",'abcat'))
print(re.search(r"ca{2,5}t",'abcaat'))
print(re.search(r"ca{2,5}t",'abcaaat'))
print(re.search(r"ca{2,5}t",'abcaaaat'))
print(re.search(r"ca{2,5}t",'abcaaaaat'))
print(re.search(r"ca{2,5}t",'abcaaaaaat'))
# Out:
# None
# <re.Match object; span=(2, 6), match='caat'>
# <re.Match object; span=(2, 7), match='caaat'>
# <re.Match object; span=(2, 8), match='caaaat'>
# <re.Match object; span=(2, 9), match='caaaaat'>
# None

# %%
import re
print(re.search(r"ab?c",'abc'))
print(re.search(r"ab?c",'ac'))
# Out:
# <re.Match object; span=(0, 3), match='abc'>
# <re.Match object; span=(0, 2), match='ac'>

# %%
import re
print(re.search(r"(ABC)+",'ABCABCABCSDS'))
# Out:
# <re.Match object; span=(0, 9), match='ABCABCABC'>

# %%
import re
p=re.compile('[a-z]+')
m=p.match('python')
print(m)
m=p.match('3 python')
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>
# None

# %%
import re
p=re.compile('[a-z]+')
m=p.search('python')
print(m)
m=p.search('3 python')
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(2, 8), match='python'>

# %%
import re
p=re.compile('[h-z]+')
result=p.findall('hello everyone, nice to meet you.')
print(result)
# Out:
# ['h', 'llo', 'v', 'ryon', 'ni', 'to', 'm', 't', 'you']

# %%
import re
p=re.compile('[h-z]+')
result=p.finditer('hello everyone, nice to meet you.')
print(result)
for r in result:
    print(r)
# Out:
# ...
# <re.Match object; span=(0, 1), match='h'>
# <re.Match object; span=(2, 5), match='llo'>
# <re.Match object; span=(7, 8), match='v'>
# <re.Match object; span=(9, 13), match='ryon'>
# <re.Match object; span=(16, 18), match='ni'>
# <re.Match object; span=(21, 23), match='to'>
# <re.Match object; span=(24, 25), match='m'>
# <re.Match object; span=(27, 28), match='t'>
# <re.Match object; span=(29, 32), match='you'>

# %%
import re
a=re.sub('Rabbit','Cat','Rabbit is Rabbit') #Rabbit을 Cat으로 바꿔라.
print(a)
# Out:
# Cat is Cat

# %%
import re
p=re.compile('[a-z]+')
m=p.search('python')
print(m)
print(m.group())
m=p.search('python')
print(m.end())
m=p.search('3 python')
print(m.group())
m=p.search('3 python')
print(m.end())
m=p.search('python')
print(m.start())
m=p.search('python')
print(m.span())
m=p.search('3 python')
print(m.start())
m=p.search('3 python')
print(m.span())
# Out:
# <re.Match object; span=(0, 6), match='python'>
# python
# 6
# python
# 8
# 0
# (0, 6)
# 2
# (2, 8)

# %%
import re
from urllib.request import urlopen
from html import unescape

f=urlopen("https://search.shopping.naver.com/search/category.nhn?cat_id=50000148")
encoding=f.info().get_content_charset(failobj='utf-8')
text=f.read().decode(encoding)

for partial_html in re.findall('<div class="tit">.*?</div>',text,re.DOTALL):
    product=re.search('title="(.*?)"',partial_html).group(1)
    product=unescape(product)
    print('제품명 :',product)
    print('-----')
# Out:
# 제품명 : 콩스콩스 원두커피 1kg 10+1
# -----
# 제품명 : 모두의커피 원두커피 1kg
# -----
# 제품명 : 로스팅전문가 진짜맛있는 당일로스팅 원두커피
# -----
# 제품명 : 워너빈 원두커피(대륙별선택가능) 1kg
# -----
# 제품명 : 일리 캡슐커피 37종 (네스프레소 호환포함)
# -----
# 제품명 : 스파클 2L
# -----
# 제품명 : 동서식품 맥심 모카골드 마일드 12g x 400개입
# -----
# 제품명 : 맥심 모카골드 400T/화이트/커피믹스/커피
# -----
# 제품명 : 네스프레소 캡슐 커피24종 우체국 당일발송/ Nespresso 캡슐
# -----
# 제품명 : 웅진식품 [웅진식품]빅토리아 탄산수/음료 500mlx40pet  11종 중 택2
# -----
# 제품명 : 안내 레이어 닫기
# -----
# 제품명 : 웅진 빅토리아 탄산수 플레인  500ml  40개
# -----
# 제품명 : 삼다수 2L
# -----
# 제품명 : 농심 백산수 2L
# -----
# 제품명 : 스파클 500ml
# -----
# 제품명 : 삼다수 500ml
# -----
# 제품명 : 일리 캡슐 커피 19종 (네스프레소 호환포함)
# -----
# 제품명 : 안심박스) 제주 삼다수 2L x10개 or 500ml x40 / 12
# -----
# 제품명 : 동서식품 맥심 화이트골드 11.7g x 400개입
# -----
# 제품명 : 코카콜라 캔/페트 업소용 190ml 245m 355ml 500ml 1.25리터
# -----
# 제품명 : [강블리라이프]수블리 미네랄 워터 2L X 36개
# -----
# 제품명 : 동서식품 맥심 모카골드 마일드 선물세트 20호
# -----
# 제품명 : 동서식품 카누 미니 다크로스트 아메리카노 0.9g x 150개입
# -----
# 제품명 : 카누 미니 다크 마일드 디카페인 스위트아메리카노 100T 150T
# -----
# ...
